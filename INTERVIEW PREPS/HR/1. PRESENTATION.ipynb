# %% [markdown]
# # Self-Introduction
#
# Hello, my name is Sergiy, and I am a dedicated professional with a unique journey, transitioning from luxury hospitality to the IT industry. My career shift began in 2019 when I decided to follow my passion for technology through self-learning. In 2021, I completed a Junior AI Engineer course at BeCode, marking a pivotal moment in my career.
#
# ## Experience at ING Belgium
#
# ### My Role and the Company
# Since 2021, I have been working at **ING Belgium**, a leading international banking institution offering innovative and tailored financial solutions to individuals and businesses.
#
# ### The Department and Its Organization
# I joined the **Platform Engineering** department, specifically the **DataCebo Squad**, a team specializing in developing solutions for data management and generation. This multidisciplinary team consisted of six members: a product owner, a scrum master, and four engineers, each responsible for technical implementation and delivery.
#
# ### The Context and Projects
# Within the team, I contributed to several key projects:
# 1. **Synthetic Data Generation**: This project aimed to produce GDPR-compliant synthetic data to support machine learning solutions and software testing while preserving data confidentiality.
# 2. **Dynamic Data Masking**: This NLP-based project focused on detecting and automatically masking sensitive data classified as C3 and C4 under GDPR.
#
# ### My Achievements and the Technical Environment
#
# #### 1. Synthetic Data Generation
# - Conducted statistical experiments to analyze the properties of generated data, including:
#   - Value distribution.
#   - Variation distance.
#   - Correlation similarity and referential integrity for multi-table datasets.
# - Contributed to multiple "shift left" projects, integrating synthetic data generation into early stages of the software development lifecycle.
# - Developed an end-to-end automated pipeline in Python for synthetic data generation. This pipeline included:
#   - Automatic validation of input data.
#   - Construction of matrices for training generation models.
#   - Detection and automated handling of PII.
#   - Integration with databases for logging results and managing user parameters.
#   - Automatic hyperparameter tuning based on the statistical properties of real data.
# - Technical stack: Python, SQL, CTGAN, TVAE, statistical tools.
#
# #### 2. Dynamic Data Masking (NLP)
# - Developed algorithms to detect and mask sensitive data (names, addresses, card numbers, etc.) in compliance with GDPR.
# - Designed features for automatic text extraction from PDFs and images using OCR.
# - Automated the generation of "cleaned" files, with sensitive data masked while maintaining usability.
# - Technical stack: Python, NLP libraries, OCR tools, web scraping, text and PDF file handling.
#
# ---
#
# ## Conclusion
# My journey reflects my ability to adapt to complex environments and solve diverse technical challenges using advanced technologies. Through my contributions to synthetic data generation and dynamic masking projects, I have gained deep expertise in Python, data science, and automated pipeline engineering.
#
# I am excited to take on new challenges in a **data science** or **Python engineering** role, where I can contribute to innovative projects and deliver impactful results.

# %% [markdown]
# # Présentation de Moi
#
# Bonjour, je m'appelle Sergiy, et je suis un professionnel dévoué avec un parcours unique, ayant évolué de l’hôtellerie de luxe à l’industrie de l’IT. Ma transition a débuté en 2019 lorsque j’ai décidé de suivre ma passion pour la technologie à travers l’auto-apprentissage. En 2021, j’ai terminé une formation en tant que Junior AI Engineer chez BeCode, ce qui a marqué un tournant décisif dans ma carrière.
#
# ## Expérience chez ING Belgium
#
# ### Mon rôle et la société
# Depuis 2021, je travaille chez **ING Belgium**, une institution bancaire internationale de premier plan, offrant des solutions financières à la fois innovantes et personnalisées pour répondre aux besoins des particuliers et des entreprises.
#
# ### Le département et son organisation
# J’ai intégré le département **Platform Engineering**, et plus précisément l’équipe **DataCebo Squad**, une équipe spécialisée dans le développement de solutions liées à la gestion et à la génération de données. Cette équipe multidisciplinaire était composée de 6 experts : un product owner, un scrum master et 4 ingénieurs, chacun ayant des responsabilités techniques spécifiques.
#
# ### Le contexte et les projets
# Au sein de cette équipe, j’ai participé à plusieurs projets clés :
# 1. **Génération de données synthétiques** : Ce projet visait à produire des données synthétiques conformes au RGPD pour permettre le développement de solutions de machine learning et le test de logiciels sans compromettre les données réelles.
# 2. **Masquage dynamique des données** : Ce projet, basé sur le NLP, avait pour objectif de détecter et masquer automatiquement les données sensibles, classifiées comme C3 et C4 dans le cadre du RGPD.
#
# ### Mes réalisations et l’environnement technique
#
# #### 1. Génération de données synthétiques
# - Réalisation d’expérimentations statistiques pour analyser les propriétés des données générées, notamment :
#   - Distribution des valeurs.
#   - Distance de variation.
#   - Similarité des corrélations et intégrité référentielle pour les ensembles de données multi-tables.
# - Contribution à plusieurs projets "shift left", intégrant la génération de données synthétiques dès les premières étapes du cycle de développement logiciel.
# - Développement d’un pipeline automatisé de bout en bout en Python pour la génération de données synthétiques. Ce pipeline intégrait :
#   - Une validation automatisée des données sources.
#   - La construction de matrices pour l’entraînement des modèles de génération.
#   - La détection et le traitement automatiques des PII.
#   - La connexion avec des bases de données pour journaliser les résultats et gérer les paramètres utilisateurs.
#   - L’ajustement automatique des hyperparamètres en fonction des propriétés statistiques des données réelles.
# - Environnement technique : Python, SQL, CTGAN, TVAE, outils statistiques.
#
# #### 2. Masquage dynamique des données (NLP)
# - Développement d’algorithmes pour détecter et masquer les données sensibles (noms, adresses, numéros de carte, etc.) conformément au RGPD.
# - Conception de fonctionnalités d’extraction automatique de texte à partir de fichiers PDF et d’images via OCR.
# - Automatisation de la génération de fichiers "nettoyés", avec masquage des données sensibles tout en conservant leur utilité.
# - Environnement technique : Python, bibliothèques NLP, OCR libraries, web scraping, manipulation des fichiers texte et PDF.
#
# ---
#
# ## Conclusion
# Mon parcours reflète ma capacité à m'adapter à des environnements complexes et à résoudre des problématiques techniques variées en utilisant des technologies avancées. Grâce à mes contributions aux projets de génération de données synthétiques et de masquage dynamique, j'ai acquis une expertise approfondie en Python, en science des données, et en ingénierie des pipelines automatisés.
#
# Je suis enthousiaste à l'idée de relever de nouveaux défis dans un rôle en **science des données** ou en **ingénierie Python**, où je pourrais contribuer à des projets innovants et avoir un impact significatif.
#
# ---
#
# Ce texte est suffisamment détaillé pour montrer votre expertise et est adaptable à différents contextes professionnels. Voulez-vous d'autres ajustements ou des exemples pour mieux structurer une présentation orale ? 😊
